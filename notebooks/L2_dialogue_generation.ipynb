# %%
import openai
import os
import argparse
import requests
import json
from dotenv import load_dotenv

# %%
load_dotenv(".env")
openai.organization = os.environ.get("OPENAI_ORG")
openai.api_key = os.environ.get("OPENAI_API_KEY")

# %%
MODEL_LIST = {
    "DeepSeek V3": {"model": "deepseek/deepseek-chat", 
                    "api_key": os.getenv("DEEPSEEK_API_KEY")},
    "QWEN 72B":{"model": "qwen/qwen-2.5-72b-instruct", 
                "api_key": os.getenv("QWEN_API_KEY")},
    "Llama 70B": {"model": "meta-llama/llama-3.3-70b-instruct",
                 "api_key": os.getenv("LLAMA_API_KEY")},
    "Claude 3.5 Haiku": {"model": "anthropic/claude-3.5-haiku", 
                        "api_key": os.getenv("CLAUDE_API_KEY")},
    "GPT 4o 2025": {"model": "gpt-4o", 
               "api_key": os.getenv("OPENAI_API_KEY")},
}

# %%
topic_list = [
    {
        "category": "Daily_Life",
        "prompts": [
            "Discuss your morning routine with a friend.",
            "Plan a weekend picnic with your family.",
            "Explain how you prepare your favorite meal to a new roommate."
        ]
    },
    {
        "category": "Shopping",
        "prompts": [
            "Ask a shop assistant for help finding a product.",
            "Negotiate a price for an item at a local market.",
            "Discuss a product return policy with a store employee."
        ]
    },
    {
        "category": "Travel_and_Transportation",
        "prompts": [
            "Describe your recent trip to a new city to a friend.",
            "Ask for directions to a nearby hotel in an unfamiliar town.",
            "Plan a group vacation, deciding on the destination and activities."
        ]
    },
    {
        "category": "Education",
        "prompts": [
            "Discuss an upcoming exam with a classmate.",
            "Explain a challenging topic to a peer in your study group.",
            "Ask your teacher for clarification on a homework assignment."
        ]
    },
    {
        "category": "Workplace",
        "prompts": [
            "Discuss a project deadline with your manager.",
            "Role-play a job interview, answering common questions.",
            "Explain a task to a new coworker."
        ]
    },
    {
        "category": "Health_and_Wellness",
        "prompts": [
            "Describe symptoms to a doctor during a visit.",
            "Give advice to a friend about staying healthy.",
            "Discuss exercise routines and fitness goals with a trainer."
        ]
    },
    {
        "category": "Social_Interactions",
        "prompts": [
            "Introduce yourself to someone at a party.",
            "Plan a birthday surprise for a friend with your group.",
            "Role-play a phone conversation with a distant relative."
        ]
    },
    {
        "category": "Problem_Solving",
        "prompts": [
            "Resolve a misunderstanding with a friend.",
            "Request assistance from customer service for a technical issue.",
            "Apologize for a mistake and offer a solution."
        ]
    },
    {
        "category": "Entertainment",
        "prompts": [
            "Discuss your favorite movies and TV shows with a friend.",
            "Plan an evening out, deciding between restaurants and activities.",
            "Recommend a book to someone and explain why they should read it."
        ]
    },
    {
        "category": "Cultural_Exchange",
        "prompts": [
            "Explain a tradition or festival from your country to a foreigner.",
            "Discuss cultural differences in dining etiquette with a friend.",
            "Ask a coworker about their favorite holiday in their country."
        ]
    }
]

new_topic_list = [
    {
        "category": "Daily Life",
        "prompts": [
        "Discuss your morning routine with a friend.",
        "Plan a weekend picnic with your family.",
        "Explain how you prepare your favorite meal to a new roommate."
        ]
    },
    {
        "category": "Shopping",
        "prompts": [
        "Ask a shop assistant for help finding a product.",
        "Negotiate a price for an item at a local market.",
        "Discuss a product return policy with a store employee."
        ]
    },
    {
        "category": "Travel and Transportation",
        "prompts": [
        "Describe your recent trip to a new city to a friend.",
        "Ask for directions to a nearby hotel in an unfamiliar town.",
        "Plan a group vacation, deciding on the destination and activities."
        ]
    },
    {
        "category": "Education",
        "prompts": [
        "Discuss an upcoming exam with a classmate.",
        "Explain a challenging topic to a peer in your study group.",
        "Ask your teacher for clarification on a homework assignment."
        ]
    },
    {
        "category": "Workplace",
        "prompts": [
        "Discuss a project deadline with your manager.",
        "Role-play a job interview, answering common questions.",
        "Explain a task to a new coworker."
        ]
    },
    {
        "category": "Health and Wellness",
        "prompts": [
        "Describe symptoms to a doctor during a visit.",
        "Give advice to a friend about staying healthy.",
        "Discuss exercise routines and fitness goals with a trainer."
        ]
    },
    {
        "category": "Social Interactions",
        "prompts": [
        "Introduce yourself to someone at a party.",
        "Plan a birthday surprise for a friend with your group.",
        "Role-play a phone conversation with a distant relative."
        ]
    },
    {
        "category": "Problem-Solving",
        "prompts": [
        "Resolve a misunderstanding with a friend.",
        "Request assistance from customer service for a technical issue.",
        "Apologize for a mistake and offer a solution."
        ]
    },
    {
        "category": "Entertainment",
        "prompts": [
        "Discuss your favorite movies and TV shows with a friend.",
        "Plan an evening out, deciding between restaurants and activities.",
        "Recommend a book to someone and explain why they should read it."
        ]
    },
    {
        "category": "Cultural Exchange",
        "prompts": [
        "Explain a tradition or festival from your country to a foreigner.",
        "Discuss cultural differences in dining etiquette with a friend.",
        "Ask a coworker about their favorite holiday in their country."
        ]
    },
            {
        "category": "Daily Conversations",
        "prompts": [
        "Talk about your favorite hobby and why you enjoy it.",
        "Discuss your plans for the weekend with a friend.",
        "Describe a recent memorable event and how it made you feel."
        ]
    },
    {
        "category": "Travel and Exploration",
        "prompts": [
        "Plan a trip to a new city with a group of friends.",
        "Describe your favorite place to visit and why it’s special.",
        "Ask for directions to a landmark in a new town."
        ]
    },
    {
        "category": "Workplace Interactions",
        "prompts": [
        "Discuss project deadlines and tasks with a coworker.",
        "Explain a process or task to a new team member.",
        "Plan a team meeting and decide on the agenda."
        ]
    },
    {
        "category": "Educational Settings",
        "prompts": [
        "Ask a teacher for clarification on an assignment.",
        "Discuss an upcoming test with a classmate and share study tips.",
        "Explain a challenging topic to a study group member."
        ]
    },
    {
        "category": "Shopping and Services",
        "prompts": [
        "Ask a shopkeeper for recommendations on a product.",
        "Discuss the features of an item before deciding to buy it.",
        "Explain an issue with a recent purchase to customer service."
        ]
    },
    {
        "category": "Health and Wellness",
        "prompts": [
        "Describe symptoms to a doctor during a consultation.",
        "Discuss exercise routines and goals with a fitness trainer.",
        "Give advice to a friend on staying healthy and active."
        ]
    },
    {
        "category": "Social Events and Gatherings",
        "prompts": [
        "Introduce yourself to someone new at a party.",
        "Plan a surprise party for a friend with a group.",
        "Talk about shared interests with someone you just met."
        ]
    },
    {
        "category": "Problem-Solving and Conflict Resolution",
        "prompts": [
        "Resolve a misunderstanding with a friend through discussion.",
        "Discuss ways to fix a technical issue with a service provider.",
        "Plan steps to address a shared problem with a coworker."
        ]
    },
    {
        "category": "Cultural Exchange and Traditions",
        "prompts": [
        "Describe a tradition or festival from your culture to a friend.",
        "Discuss differences in dining etiquette with someone from another culture.",
        "Plan a cultural event to share your traditions with others."
        ]
    },
    {
        "category": "Personal Goals and Experiences",
        "prompts": [
        "Talk about your goals for the next year and how you plan to achieve them.",
        "Describe a skill you want to learn and why it’s important to you.",
        "Discuss a recent personal achievement and what it means to you."
        ]
    }
]

# %%
def read_instruction(instruction_path):
    with open(instruction_path, 'r', encoding='utf-8') as file:
        instruction = file.read()
    return instruction

def request(api_key, 
            model, 
            output_dir_path, 
            system_instruction, 
            assist_instruction, 
            topic_list, 
            repeat_id=0,
            count=0):  # parameters
    for i in range(len(topic_list)):
        for j in range(len(topic_list[i]["prompts"])):
            
            print(f"Conversation Count: {count}, Category: {topic_list[i]['category']}")
            count += 1
            file_save_path = os.path.join(output_dir_path, f"{topic_list[i]['category']}_{j+repeat_id*3}.txt")
            if os.path.exists(file_save_path):
                continue

            message = assist_instruction.format(text=topic_list[i]["prompts"][j])
            #print(model)
            if model == "gpt-4o":
                messages = [
                    {"role": "system", "content": system_instruction},
                    {"role": "user", "content": message},
                ]
                try:
                    response = openai.chat.completions.create(
                        model=model,
                        messages=messages,
                        temperature=0,
                    )
                    ans_model = response.choices[0].message
                    #print(f"Answer: {ans_model}")
                except Exception as e:
                    print(f"Answer: {ans_model}")
                    print(f"Error: {e}")
            else:
                try:
                    messages = [
                        {"role": "system", "content": system_instruction},
                        {"role": "user", "content": message},
                    ]
                    response = requests.post(
                        url="https://openrouter.ai/api/v1/chat/completions",
                        headers={
                            f"Authorization": f"Bearer {api_key}",
                        },
                        data=json.dumps({
                            "model": f"{model}",
                            "messages": messages
                        })
                    )
                    try:
                        if response.status_code in [200, 401]:
                            response_data = response.json()    
                            ans_model = response_data['choices'][0]['message'] 
                        else:
                            print(f"Method 1 Reponse Data: {response_data}")
                            print(f"Error: Received status code {response.status_code}")
                    except Exception as e:
                        print(f"Error: {e}")
                        

                except requests.exceptions.RequestException as e:
                    messages[0] = {"role": "user", "content": system_instruction}
                    try:
                        response = requests.post(
                            url="https://openrouter.ai/api/v1/chat/completions",
                            headers={
                                "Authorization": f"Bearer f{api_key}",
                            },
                            data=json.dumps({
                                "model": f"{model}",
                                "messages": messages
                            })
                        )
                        try:
                            if response.status_code in [200, 401]:
                                response_data = response.json()  
                                ans_model = response_data['choices'][0]['message']  
                            else:
                                print("Method 2 Response Data: ", response_data)
                                print(f"Error: Received status code {response.status_code}")
                        except:
                            print(f"Error: {e}")

                    except requests.exceptions.RequestException as e:
                        print(f"Request failed after retry: {e}")

            
            # print(f"Answer: {ans_model}")
            # ans_model = ans_model[3:-3].strip()
            # ans_model = ans_model.lstrip('json').strip()   
            with open(file_save_path, "w") as file:
                file.write(ans_model.content)
    return  count

# %%
model_name = "GPT 4o 2025"
api_key = MODEL_LIST[model_name]["api_key"]
model = MODEL_LIST[model_name]["model"]

context_instruction_dir_path = "../lib/instructions/context_instructions"  
generation_instruction_dir_path = "../lib/instructions/generation_instructions" 
output_dir = f"../data/{model_name}_output/"

count = 0
for context_instruction, generation_instruction in zip(sorted(os.listdir(context_instruction_dir_path)), 
                                                       sorted(os.listdir(generation_instruction_dir_path))):
    language = context_instruction.strip(".txt")
    print("*"*50)
    print(f"Language: {language}")
    context_instruction_path = os.path.join(context_instruction_dir_path, context_instruction)
    generation_instruction_path = os.path.join(generation_instruction_dir_path, generation_instruction)
    system_instruction = read_instruction(context_instruction_path)
    instruction = read_instruction(generation_instruction_path)
    output_dir_path = output_dir + f"{language}_dialog"
    if not os.path.exists(output_dir_path):
        os.makedirs(output_dir_path)
    count = request(api_key, model, output_dir_path, system_instruction, instruction, new_topic_list, repeat_id=0, count=count)
# Out:
# **************************************************
# Language: cantonese
# Conversation Count: 0, Category: Daily Life
# Conversation Count: 1, Category: Daily Life
# Conversation Count: 2, Category: Daily Life
# Conversation Count: 3, Category: Shopping
# Conversation Count: 4, Category: Shopping
# Conversation Count: 5, Category: Shopping
# Conversation Count: 6, Category: Travel and Transportation
# Conversation Count: 7, Category: Travel and Transportation
# Conversation Count: 8, Category: Travel and Transportation
# Conversation Count: 9, Category: Education
# Conversation Count: 10, Category: Education
# Conversation Count: 11, Category: Education
# Conversation Count: 12, Category: Workplace
# Conversation Count: 13, Category: Workplace
# Conversation Count: 14, Category: Workplace
# Conversation Count: 15, Category: Health and Wellness
# Conversation Count: 16, Category: Health and Wellness
# Conversation Count: 17, Category: Health and Wellness
# Conversation Count: 18, Category: Social Interactions
# Conversation Count: 19, Category: Social Interactions
# Conversation Count: 20, Category: Social Interactions
# Conversation Count: 21, Category: Problem-Solving
# Conversation Count: 22, Category: Problem-Solving
# Conversation Count: 23, Category: Problem-Solving
# Conversation Count: 24, Category: Entertainment
# Conversation Count: 25, Category: Entertainment
# Conversation Count: 26, Category: Entertainment
# Conversation Count: 27, Category: Cultural Exchange
# Conversation Count: 28, Category: Cultural Exchange
# Conversation Count: 29, Category: Cultural Exchange
# Conversation Count: 30, Category: Daily Conversations
# Conversation Count: 31, Category: Daily Conversations
# Conversation Count: 32, Category: Daily Conversations
# Conversation Count: 33, Category: Travel and Exploration
# Conversation Count: 34, Category: Travel and Exploration
# Conversation Count: 35, Category: Travel and Exploration
# Conversation Count: 36, Category: Workplace Interactions
# Conversation Count: 37, Category: Workplace Interactions
# Conversation Count: 38, Category: Workplace Interactions
# Conversation Count: 39, Category: Educational Settings
# Conversation Count: 40, Category: Educational Settings
# Conversation Count: 41, Category: Educational Settings
# Conversation Count: 42, Category: Shopping and Services
# Conversation Count: 43, Category: Shopping and Services
# Conversation Count: 44, Category: Shopping and Services
# Conversation Count: 45, Category: Health and Wellness
# Conversation Count: 46, Category: Health and Wellness
# Conversation Count: 47, Category: Health and Wellness
# Conversation Count: 48, Category: Social Events and Gatherings
# Conversation Count: 49, Category: Social Events and Gatherings
# Conversation Count: 50, Category: Social Events and Gatherings
# Conversation Count: 51, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 52, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 53, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 54, Category: Cultural Exchange and Traditions
# Conversation Count: 55, Category: Cultural Exchange and Traditions
# Conversation Count: 56, Category: Cultural Exchange and Traditions
# Conversation Count: 57, Category: Personal Goals and Experiences
# Conversation Count: 58, Category: Personal Goals and Experiences
# Conversation Count: 59, Category: Personal Goals and Experiences
# **************************************************
# Language: english
# Conversation Count: 60, Category: Daily Life
# Conversation Count: 61, Category: Daily Life
# Conversation Count: 62, Category: Daily Life
# Conversation Count: 63, Category: Shopping
# Conversation Count: 64, Category: Shopping
# Conversation Count: 65, Category: Shopping
# Conversation Count: 66, Category: Travel and Transportation
# Conversation Count: 67, Category: Travel and Transportation
# Conversation Count: 68, Category: Travel and Transportation
# Conversation Count: 69, Category: Education
# Conversation Count: 70, Category: Education
# Conversation Count: 71, Category: Education
# Conversation Count: 72, Category: Workplace
# Conversation Count: 73, Category: Workplace
# Conversation Count: 74, Category: Workplace
# Conversation Count: 75, Category: Health and Wellness
# Conversation Count: 76, Category: Health and Wellness
# Conversation Count: 77, Category: Health and Wellness
# Conversation Count: 78, Category: Social Interactions
# Conversation Count: 79, Category: Social Interactions
# Conversation Count: 80, Category: Social Interactions
# Conversation Count: 81, Category: Problem-Solving
# Conversation Count: 82, Category: Problem-Solving
# Conversation Count: 83, Category: Problem-Solving
# Conversation Count: 84, Category: Entertainment
# Conversation Count: 85, Category: Entertainment
# Conversation Count: 86, Category: Entertainment
# Conversation Count: 87, Category: Cultural Exchange
# Conversation Count: 88, Category: Cultural Exchange
# Conversation Count: 89, Category: Cultural Exchange
# Conversation Count: 90, Category: Daily Conversations
# Conversation Count: 91, Category: Daily Conversations
# Conversation Count: 92, Category: Daily Conversations
# Conversation Count: 93, Category: Travel and Exploration
# Conversation Count: 94, Category: Travel and Exploration
# Conversation Count: 95, Category: Travel and Exploration
# Conversation Count: 96, Category: Workplace Interactions
# Conversation Count: 97, Category: Workplace Interactions
# Conversation Count: 98, Category: Workplace Interactions
# Conversation Count: 99, Category: Educational Settings
# Conversation Count: 100, Category: Educational Settings
# Conversation Count: 101, Category: Educational Settings
# Conversation Count: 102, Category: Shopping and Services
# Conversation Count: 103, Category: Shopping and Services
# Conversation Count: 104, Category: Shopping and Services
# Conversation Count: 105, Category: Health and Wellness
# Conversation Count: 106, Category: Health and Wellness
# Conversation Count: 107, Category: Health and Wellness
# Conversation Count: 108, Category: Social Events and Gatherings
# Conversation Count: 109, Category: Social Events and Gatherings
# Conversation Count: 110, Category: Social Events and Gatherings
# Conversation Count: 111, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 112, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 113, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 114, Category: Cultural Exchange and Traditions
# Conversation Count: 115, Category: Cultural Exchange and Traditions
# Conversation Count: 116, Category: Cultural Exchange and Traditions
# Conversation Count: 117, Category: Personal Goals and Experiences
# Conversation Count: 118, Category: Personal Goals and Experiences
# Conversation Count: 119, Category: Personal Goals and Experiences
# **************************************************
# Language: japanese
# Conversation Count: 120, Category: Daily Life
# Conversation Count: 121, Category: Daily Life
# Conversation Count: 122, Category: Daily Life
# Conversation Count: 123, Category: Shopping
# Conversation Count: 124, Category: Shopping
# Conversation Count: 125, Category: Shopping
# Conversation Count: 126, Category: Travel and Transportation
# Conversation Count: 127, Category: Travel and Transportation
# Conversation Count: 128, Category: Travel and Transportation
# Conversation Count: 129, Category: Education
# Conversation Count: 130, Category: Education
# Conversation Count: 131, Category: Education
# Conversation Count: 132, Category: Workplace
# Conversation Count: 133, Category: Workplace
# Conversation Count: 134, Category: Workplace
# Conversation Count: 135, Category: Health and Wellness
# Conversation Count: 136, Category: Health and Wellness
# Conversation Count: 137, Category: Health and Wellness
# Conversation Count: 138, Category: Social Interactions
# Conversation Count: 139, Category: Social Interactions
# Conversation Count: 140, Category: Social Interactions
# Conversation Count: 141, Category: Problem-Solving
# Conversation Count: 142, Category: Problem-Solving
# Conversation Count: 143, Category: Problem-Solving
# Conversation Count: 144, Category: Entertainment
# Conversation Count: 145, Category: Entertainment
# Conversation Count: 146, Category: Entertainment
# Conversation Count: 147, Category: Cultural Exchange
# Conversation Count: 148, Category: Cultural Exchange
# Conversation Count: 149, Category: Cultural Exchange
# Conversation Count: 150, Category: Daily Conversations
# Conversation Count: 151, Category: Daily Conversations
# Conversation Count: 152, Category: Daily Conversations
# Conversation Count: 153, Category: Travel and Exploration
# Conversation Count: 154, Category: Travel and Exploration
# Conversation Count: 155, Category: Travel and Exploration
# Conversation Count: 156, Category: Workplace Interactions
# Conversation Count: 157, Category: Workplace Interactions
# Conversation Count: 158, Category: Workplace Interactions
# Conversation Count: 159, Category: Educational Settings
# Conversation Count: 160, Category: Educational Settings
# Conversation Count: 161, Category: Educational Settings
# Conversation Count: 162, Category: Shopping and Services
# Conversation Count: 163, Category: Shopping and Services
# Conversation Count: 164, Category: Shopping and Services
# Conversation Count: 165, Category: Health and Wellness
# Conversation Count: 166, Category: Health and Wellness
# Conversation Count: 167, Category: Health and Wellness
# Conversation Count: 168, Category: Social Events and Gatherings
# Conversation Count: 169, Category: Social Events and Gatherings
# Conversation Count: 170, Category: Social Events and Gatherings
# Conversation Count: 171, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 172, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 173, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 174, Category: Cultural Exchange and Traditions
# Conversation Count: 175, Category: Cultural Exchange and Traditions
# Conversation Count: 176, Category: Cultural Exchange and Traditions
# Conversation Count: 177, Category: Personal Goals and Experiences
# Conversation Count: 178, Category: Personal Goals and Experiences
# Conversation Count: 179, Category: Personal Goals and Experiences
# **************************************************
# Language: korean
# Conversation Count: 180, Category: Daily Life
# Conversation Count: 181, Category: Daily Life
# Conversation Count: 182, Category: Daily Life
# Conversation Count: 183, Category: Shopping
# Conversation Count: 184, Category: Shopping
# Conversation Count: 185, Category: Shopping
# Conversation Count: 186, Category: Travel and Transportation
# Conversation Count: 187, Category: Travel and Transportation
# Conversation Count: 188, Category: Travel and Transportation
# Conversation Count: 189, Category: Education
# Conversation Count: 190, Category: Education
# Conversation Count: 191, Category: Education
# Conversation Count: 192, Category: Workplace
# Conversation Count: 193, Category: Workplace
# Conversation Count: 194, Category: Workplace
# Conversation Count: 195, Category: Health and Wellness
# Conversation Count: 196, Category: Health and Wellness
# Conversation Count: 197, Category: Health and Wellness
# Conversation Count: 198, Category: Social Interactions
# Conversation Count: 199, Category: Social Interactions
# Conversation Count: 200, Category: Social Interactions
# Conversation Count: 201, Category: Problem-Solving
# Conversation Count: 202, Category: Problem-Solving
# Conversation Count: 203, Category: Problem-Solving
# Conversation Count: 204, Category: Entertainment
# Conversation Count: 205, Category: Entertainment
# Conversation Count: 206, Category: Entertainment
# Conversation Count: 207, Category: Cultural Exchange
# Conversation Count: 208, Category: Cultural Exchange
# Conversation Count: 209, Category: Cultural Exchange
# Conversation Count: 210, Category: Daily Conversations
# Conversation Count: 211, Category: Daily Conversations
# Conversation Count: 212, Category: Daily Conversations
# Conversation Count: 213, Category: Travel and Exploration
# Conversation Count: 214, Category: Travel and Exploration
# Conversation Count: 215, Category: Travel and Exploration
# Conversation Count: 216, Category: Workplace Interactions
# Conversation Count: 217, Category: Workplace Interactions
# Conversation Count: 218, Category: Workplace Interactions
# Conversation Count: 219, Category: Educational Settings
# Conversation Count: 220, Category: Educational Settings
# Conversation Count: 221, Category: Educational Settings
# Conversation Count: 222, Category: Shopping and Services
# Conversation Count: 223, Category: Shopping and Services
# Conversation Count: 224, Category: Shopping and Services
# Conversation Count: 225, Category: Health and Wellness
# Conversation Count: 226, Category: Health and Wellness
# Conversation Count: 227, Category: Health and Wellness
# Conversation Count: 228, Category: Social Events and Gatherings
# Conversation Count: 229, Category: Social Events and Gatherings
# Conversation Count: 230, Category: Social Events and Gatherings
# Conversation Count: 231, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 232, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 233, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 234, Category: Cultural Exchange and Traditions
# Conversation Count: 235, Category: Cultural Exchange and Traditions
# Conversation Count: 236, Category: Cultural Exchange and Traditions
# Conversation Count: 237, Category: Personal Goals and Experiences
# Conversation Count: 238, Category: Personal Goals and Experiences
# Conversation Count: 239, Category: Personal Goals and Experiences
# **************************************************
# Language: malay
# Conversation Count: 240, Category: Daily Life
# Conversation Count: 241, Category: Daily Life
# Conversation Count: 242, Category: Daily Life
# Conversation Count: 243, Category: Shopping
# Conversation Count: 244, Category: Shopping
# Conversation Count: 245, Category: Shopping
# Conversation Count: 246, Category: Travel and Transportation
# Conversation Count: 247, Category: Travel and Transportation
# Conversation Count: 248, Category: Travel and Transportation
# Conversation Count: 249, Category: Education
# Conversation Count: 250, Category: Education
# Conversation Count: 251, Category: Education
# Conversation Count: 252, Category: Workplace
# Conversation Count: 253, Category: Workplace
# Conversation Count: 254, Category: Workplace
# Conversation Count: 255, Category: Health and Wellness
# Conversation Count: 256, Category: Health and Wellness
# Conversation Count: 257, Category: Health and Wellness
# Conversation Count: 258, Category: Social Interactions
# Conversation Count: 259, Category: Social Interactions
# Conversation Count: 260, Category: Social Interactions
# Conversation Count: 261, Category: Problem-Solving
# Conversation Count: 262, Category: Problem-Solving
# Conversation Count: 263, Category: Problem-Solving
# Conversation Count: 264, Category: Entertainment
# Conversation Count: 265, Category: Entertainment
# Conversation Count: 266, Category: Entertainment
# Conversation Count: 267, Category: Cultural Exchange
# Conversation Count: 268, Category: Cultural Exchange
# Conversation Count: 269, Category: Cultural Exchange
# Conversation Count: 270, Category: Daily Conversations
# Conversation Count: 271, Category: Daily Conversations
# Conversation Count: 272, Category: Daily Conversations
# Conversation Count: 273, Category: Travel and Exploration
# Conversation Count: 274, Category: Travel and Exploration
# Conversation Count: 275, Category: Travel and Exploration
# Conversation Count: 276, Category: Workplace Interactions
# Conversation Count: 277, Category: Workplace Interactions
# Conversation Count: 278, Category: Workplace Interactions
# Conversation Count: 279, Category: Educational Settings
# Conversation Count: 280, Category: Educational Settings
# Conversation Count: 281, Category: Educational Settings
# Conversation Count: 282, Category: Shopping and Services
# Conversation Count: 283, Category: Shopping and Services
# Conversation Count: 284, Category: Shopping and Services
# Conversation Count: 285, Category: Health and Wellness
# Conversation Count: 286, Category: Health and Wellness
# Conversation Count: 287, Category: Health and Wellness
# Conversation Count: 288, Category: Social Events and Gatherings
# Conversation Count: 289, Category: Social Events and Gatherings
# Conversation Count: 290, Category: Social Events and Gatherings
# Conversation Count: 291, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 292, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 293, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 294, Category: Cultural Exchange and Traditions
# Conversation Count: 295, Category: Cultural Exchange and Traditions
# Conversation Count: 296, Category: Cultural Exchange and Traditions
# Conversation Count: 297, Category: Personal Goals and Experiences
# Conversation Count: 298, Category: Personal Goals and Experiences
# Conversation Count: 299, Category: Personal Goals and Experiences
# **************************************************
# Language: mandarin
# Conversation Count: 300, Category: Daily Life
# Conversation Count: 301, Category: Daily Life
# Conversation Count: 302, Category: Daily Life
# Conversation Count: 303, Category: Shopping
# Conversation Count: 304, Category: Shopping
# Conversation Count: 305, Category: Shopping
# Conversation Count: 306, Category: Travel and Transportation
# Conversation Count: 307, Category: Travel and Transportation
# Conversation Count: 308, Category: Travel and Transportation
# Conversation Count: 309, Category: Education
# Conversation Count: 310, Category: Education
# Conversation Count: 311, Category: Education
# Conversation Count: 312, Category: Workplace
# Conversation Count: 313, Category: Workplace
# Conversation Count: 314, Category: Workplace
# Conversation Count: 315, Category: Health and Wellness
# Conversation Count: 316, Category: Health and Wellness
# Conversation Count: 317, Category: Health and Wellness
# Conversation Count: 318, Category: Social Interactions
# Conversation Count: 319, Category: Social Interactions
# Conversation Count: 320, Category: Social Interactions
# Conversation Count: 321, Category: Problem-Solving
# Conversation Count: 322, Category: Problem-Solving
# Conversation Count: 323, Category: Problem-Solving
# Conversation Count: 324, Category: Entertainment
# Conversation Count: 325, Category: Entertainment
# Conversation Count: 326, Category: Entertainment
# Conversation Count: 327, Category: Cultural Exchange
# Conversation Count: 328, Category: Cultural Exchange
# Conversation Count: 329, Category: Cultural Exchange
# Conversation Count: 330, Category: Daily Conversations
# Conversation Count: 331, Category: Daily Conversations
# Conversation Count: 332, Category: Daily Conversations
# Conversation Count: 333, Category: Travel and Exploration
# Conversation Count: 334, Category: Travel and Exploration
# Conversation Count: 335, Category: Travel and Exploration
# Conversation Count: 336, Category: Workplace Interactions
# Conversation Count: 337, Category: Workplace Interactions
# Conversation Count: 338, Category: Workplace Interactions
# Conversation Count: 339, Category: Educational Settings
# Conversation Count: 340, Category: Educational Settings
# Conversation Count: 341, Category: Educational Settings
# Conversation Count: 342, Category: Shopping and Services
# Conversation Count: 343, Category: Shopping and Services
# Conversation Count: 344, Category: Shopping and Services
# Conversation Count: 345, Category: Health and Wellness
# Conversation Count: 346, Category: Health and Wellness
# Conversation Count: 347, Category: Health and Wellness
# Conversation Count: 348, Category: Social Events and Gatherings
# Conversation Count: 349, Category: Social Events and Gatherings
# Conversation Count: 350, Category: Social Events and Gatherings
# Conversation Count: 351, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 352, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 353, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 354, Category: Cultural Exchange and Traditions
# Conversation Count: 355, Category: Cultural Exchange and Traditions
# Conversation Count: 356, Category: Cultural Exchange and Traditions
# Conversation Count: 357, Category: Personal Goals and Experiences
# Conversation Count: 358, Category: Personal Goals and Experiences
# Conversation Count: 359, Category: Personal Goals and Experiences
# **************************************************
# Language: hai
# Conversation Count: 360, Category: Daily Life
# Conversation Count: 361, Category: Daily Life
# Conversation Count: 362, Category: Daily Life
# Conversation Count: 363, Category: Shopping
# Conversation Count: 364, Category: Shopping
# Conversation Count: 365, Category: Shopping
# Conversation Count: 366, Category: Travel and Transportation
# Conversation Count: 367, Category: Travel and Transportation
# Conversation Count: 368, Category: Travel and Transportation
# Conversation Count: 369, Category: Education
# Conversation Count: 370, Category: Education
# Conversation Count: 371, Category: Education
# Conversation Count: 372, Category: Workplace
# Conversation Count: 373, Category: Workplace
# Conversation Count: 374, Category: Workplace
# Conversation Count: 375, Category: Health and Wellness
# Conversation Count: 376, Category: Health and Wellness
# Conversation Count: 377, Category: Health and Wellness
# Conversation Count: 378, Category: Social Interactions
# Conversation Count: 379, Category: Social Interactions
# Conversation Count: 380, Category: Social Interactions
# Conversation Count: 381, Category: Problem-Solving
# Conversation Count: 382, Category: Problem-Solving
# Conversation Count: 383, Category: Problem-Solving
# Conversation Count: 384, Category: Entertainment
# Conversation Count: 385, Category: Entertainment
# Conversation Count: 386, Category: Entertainment
# Conversation Count: 387, Category: Cultural Exchange
# Conversation Count: 388, Category: Cultural Exchange
# Conversation Count: 389, Category: Cultural Exchange
# Conversation Count: 390, Category: Daily Conversations
# Conversation Count: 391, Category: Daily Conversations
# Conversation Count: 392, Category: Daily Conversations
# Conversation Count: 393, Category: Travel and Exploration
# Conversation Count: 394, Category: Travel and Exploration
# Conversation Count: 395, Category: Travel and Exploration
# Conversation Count: 396, Category: Workplace Interactions
# Conversation Count: 397, Category: Workplace Interactions
# Conversation Count: 398, Category: Workplace Interactions
# Conversation Count: 399, Category: Educational Settings
# Conversation Count: 400, Category: Educational Settings
# Conversation Count: 401, Category: Educational Settings
# Conversation Count: 402, Category: Shopping and Services
# Conversation Count: 403, Category: Shopping and Services
# Conversation Count: 404, Category: Shopping and Services
# Conversation Count: 405, Category: Health and Wellness
# Conversation Count: 406, Category: Health and Wellness
# Conversation Count: 407, Category: Health and Wellness
# Conversation Count: 408, Category: Social Events and Gatherings
# Conversation Count: 409, Category: Social Events and Gatherings
# Conversation Count: 410, Category: Social Events and Gatherings
# Conversation Count: 411, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 412, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 413, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 414, Category: Cultural Exchange and Traditions
# Conversation Count: 415, Category: Cultural Exchange and Traditions
# Conversation Count: 416, Category: Cultural Exchange and Traditions
# Conversation Count: 417, Category: Personal Goals and Experiences
# Conversation Count: 418, Category: Personal Goals and Experiences
# Conversation Count: 419, Category: Personal Goals and Experiences
# **************************************************
# Language: urdu
# Conversation Count: 420, Category: Daily Life
# Conversation Count: 421, Category: Daily Life
# Conversation Count: 422, Category: Daily Life
# Conversation Count: 423, Category: Shopping
# Conversation Count: 424, Category: Shopping
# Conversation Count: 425, Category: Shopping
# Conversation Count: 426, Category: Travel and Transportation
# Conversation Count: 427, Category: Travel and Transportation
# Conversation Count: 428, Category: Travel and Transportation
# Conversation Count: 429, Category: Education
# Conversation Count: 430, Category: Education
# Conversation Count: 431, Category: Education
# Conversation Count: 432, Category: Workplace
# Conversation Count: 433, Category: Workplace
# Conversation Count: 434, Category: Workplace
# Conversation Count: 435, Category: Health and Wellness
# Conversation Count: 436, Category: Health and Wellness
# Conversation Count: 437, Category: Health and Wellness
# Conversation Count: 438, Category: Social Interactions
# Conversation Count: 439, Category: Social Interactions
# Conversation Count: 440, Category: Social Interactions
# Conversation Count: 441, Category: Problem-Solving
# Conversation Count: 442, Category: Problem-Solving
# Conversation Count: 443, Category: Problem-Solving
# Conversation Count: 444, Category: Entertainment
# Conversation Count: 445, Category: Entertainment
# Conversation Count: 446, Category: Entertainment
# Conversation Count: 447, Category: Cultural Exchange
# Conversation Count: 448, Category: Cultural Exchange
# Conversation Count: 449, Category: Cultural Exchange
# Conversation Count: 450, Category: Daily Conversations
# Conversation Count: 451, Category: Daily Conversations
# Conversation Count: 452, Category: Daily Conversations
# Conversation Count: 453, Category: Travel and Exploration
# Conversation Count: 454, Category: Travel and Exploration
# Conversation Count: 455, Category: Travel and Exploration
# Conversation Count: 456, Category: Workplace Interactions
# Conversation Count: 457, Category: Workplace Interactions
# Conversation Count: 458, Category: Workplace Interactions
# Conversation Count: 459, Category: Educational Settings
# Conversation Count: 460, Category: Educational Settings
# Conversation Count: 461, Category: Educational Settings
# Conversation Count: 462, Category: Shopping and Services
# Conversation Count: 463, Category: Shopping and Services
# Conversation Count: 464, Category: Shopping and Services
# Conversation Count: 465, Category: Health and Wellness
# Conversation Count: 466, Category: Health and Wellness
# Conversation Count: 467, Category: Health and Wellness
# Conversation Count: 468, Category: Social Events and Gatherings
# Conversation Count: 469, Category: Social Events and Gatherings
# Conversation Count: 470, Category: Social Events and Gatherings
# Conversation Count: 471, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 472, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 473, Category: Problem-Solving and Conflict Resolution
# Conversation Count: 474, Category: Cultural Exchange and Traditions
# Conversation Count: 475, Category: Cultural Exchange and Traditions
# Conversation Count: 476, Category: Cultural Exchange and Traditions
# Conversation Count: 477, Category: Personal Goals and Experiences
# Conversation Count: 478, Category: Personal Goals and Experiences
# Conversation Count: 479, Category: Personal Goals and Experiences
