# %%
import openai
import pandas as pd
import numpy as np
import os
import json
import random
from dotenv import load_dotenv
import re

# %%
load_dotenv(".env")
# Out:
# True

# %%
openai.organization = os.environ.get("OPENAI_ORG")
openai.api_key = os.environ.get("OPENAI_API_KEY")

# %%
ANNOTATION_MODEL = "gpt-4o"
language_list = ['HKG', 'THA', 'JPN', 'KOR', 'MYS', 'CHN', 'ENS', 'PAK']
#can also try other models as well

# %%
def parse_filename(filename):
    pattern = r"SD_(\w+)_\d+_.*_(\d+)_([\w+]+)"
    match = re.match(pattern, filename)
    if match:
        language = match.group(1) 
        number = match.group(2)    
        chapter = match.group(3)   
        return language, number, chapter
    return None, None, None

def read_instruction(instruction_path):
    with open(instruction_path, 'r', encoding='utf-8') as file:
        instruction = file.read()
    return instruction

def replace_placeholder_with_text(original_string, text_string):
    return original_string.replace("{text}", text_string)

def format_prompt(system_instruction, instruction, input):
    #print(f"Text: {input}")
    #print(f"Instruction: {instruction}")
    message = replace_placeholder_with_text(instruction, input) 
    messages = [
        {"role": "system", "content": system_instruction},
        {"role": "user", "content": message},
    ]
    return messages

def fix_json_trailing_commas(json_string):
    json_string = re.sub(r',\s*([\]}])', r'\1', json_string)
    return json_string

def request(samples_path, output_path, system_instruction, prompt_type):  # parameters
    for file_name in sorted(os.listdir(samples_path)):
        print(file_name)
        language, _, _ = parse_filename(file_name)
        if language not in language_list:
            continue
        if file_name.endswith('.txt'):
            file_path = os.path.join(samples_path, file_name)
            json_name = os.path.splitext(file_name)[0] + '.json'
            output_json_path = os.path.join(output_path, json_name)
            if os.path.exists(output_json_path):
                continue
            
            with open(file_path, 'r', encoding='utf-8') as file:
                sample = file.read()
                messages = format_prompt(system_instruction, prompt_type, sample)
                response = openai.chat.completions.create(
                    model=ANNOTATION_MODEL,
                    messages=messages,
                    temperature=0,
                )
                ans_model = response.choices[0].message.content
                print('===================')
                ans_model = ans_model[3:-3].strip()
                ans_model = ans_model.lstrip('json').strip()
                ans_model = ans_model.replace('}\n{', '},\n{')
                ans_model = "[" + ans_model + "]"
                ans_model = re.sub(r'\bTrue\b', 'true', ans_model)
                ans_model = re.sub(r'\bFalse\b', 'false', ans_model)
                ans_model = fix_json_trailing_commas(ans_model)
                #print(ans_model)
                try:
                    data = json.loads(ans_model)
                    print("Loading Successful")
                except Exception as e: 
                    print(ans_model)
                    print(f"Error in json: {e}")
                    continue
                with open(output_json_path, 'w', encoding='utf-8') as annot_file:
                    json.dump(data, annot_file, ensure_ascii=False, indent=4)
    return

# %%
GENERATE_MODEL = "ICNALE"
output_dir = f"../annotations/{GENERATE_MODEL}_output"
input_dir =  f"../data/{GENERATE_MODEL}"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
if not os.path.exists(input_dir):
    os.mkdir(input_dir)
    
system_instruction_path = "../lib/instructions/annotation_instructions/system_instruction.txt"
system_instruction = read_instruction(system_instruction_path)
assist_instruction_dir = "../lib/instructions/annotation_instructions/assist_instructions"

#print(system_instruction)

for instruction in os.listdir(assist_instruction_dir):
    instruction_path = os.path.join(assist_instruction_dir, instruction)
    assist_instruction = read_instruction(instruction_path)
    instruction_name = instruction.strip(".txt")
    output_path = os.path.join(output_dir, f"{GENERATE_MODEL}_generation_{instruction_name}")
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    for item in sorted(os.listdir(input_dir)):
        sample_path = os.path.join(input_dir, item)
        annotation_path = os.path.join(output_path, item)
        if not os.path.exists(annotation_path):
            os.mkdir(annotation_path)
        try:
            request(sample_path, annotation_path, system_instruction, assist_instruction)
        except Exception as e:
            print(f"Error: {e}")
            continue
# Out:
# SD_CHN_01_XXX_INT_xx_001_B1_2.txt
# SD_CHN_01_XXX_INT_xx_002_B1_1.txt
# SD_CHN_01_XXX_INT_xx_003_B2_0.txt
# SD_CHN_01_XXX_INT_xx_004_B1_2.txt
# SD_CHN_01_XXX_INT_xx_005_B1_2.txt
# SD_CHN_01_XXX_INT_xx_006_B2_0.txt
# SD_CHN_01_XXX_INT_xx_007_A2.0.txt
# SD_CHN_01_XXX_INT_xx_008_B2_0.txt
# SD_CHN_01_XXX_INT_xx_009_B2_0.txt
# SD_CHN_01_XXX_INT_xx_010_B1_2.txt
# SD_CHN_01_XXX_INT_xx_011_B1_1.txt
# SD_CHN_01_XXX_INT_xx_012_B2_0.txt
# SD_CHN_01_XXX_INT_xx_013_B1_2.txt
# SD_CHN_01_XXX_INT_xx_014_B1_2.txt
# SD_CHN_01_XXX_INT_xx_015_B1_1.txt
# SD_CHN_01_XXX_INT_xx_016_B2_0.txt
# SD_CHN_01_XXX_INT_xx_017_B2_0.txt
# SD_CHN_01_XXX_INT_xx_018_B1_1.txt
# SD_CHN_01_XXX_INT_xx_019_B2_0.txt
# SD_CHN_01_XXX_INT_xx_020_B1_2.txt
# SD_CHN_01_XXX_INT_xx_021_B1_2.txt
# SD_CHN_01_XXX_INT_xx_022_B2_0.txt
# SD_CHN_01_XXX_INT_xx_023_B1_2.txt
# SD_CHN_01_XXX_INT_xx_024_B2_0.txt
# SD_CHN_01_XXX_INT_xx_025_B2_0.txt
# SD_CHN_01_XXX_INT_xx_026_B1_2.txt
# SD_CHN_01_XXX_INT_xx_027_B1_1.txt
# SD_CHN_01_XXX_INT_xx_028_B1_2.txt
# SD_CHN_01_XXX_INT_xx_029_B1_1.txt
# SD_CHN_01_XXX_INT_xx_030_B1_2.txt
# SD_CHN_01_XXX_INT_xx_031_B1_2.txt
# SD_CHN_01_XXX_INT_xx_032_B2_0.txt
# SD_CHN_01_XXX_INT_xx_033_B2_0.txt
# SD_CHN_01_XXX_INT_xx_034_A2.0.txt
# SD_CHN_01_XXX_INT_xx_035_B2_0.txt
# SD_CHN_01_XXX_INT_xx_036_B1_1.txt
# SD_CHN_01_XXX_INT_xx_037_B1_2.txt
# SD_CHN_01_XXX_INT_xx_038_B2_0.txt
# SD_CHN_01_XXX_INT_xx_039_B1_1.txt
# SD_CHN_01_XXX_INT_xx_040_B1_2.txt
# SD_CHN_01_XXX_INT_xx_041_B1_2.txt
# SD_CHN_01_XXX_INT_xx_042_B1_2.txt
# SD_CHN_01_XXX_INT_xx_043_B1_1.txt
# SD_CHN_01_XXX_INT_xx_044_A2.0.txt
# SD_CHN_01_XXX_INT_xx_045_B2_0.txt
# SD_CHN_01_XXX_INT_xx_046_B2_0.txt
# SD_CHN_01_XXX_INT_xx_047_B1_1.txt
# SD_CHN_01_XXX_INT_xx_048_B2_0.txt
# SD_CHN_01_XXX_INT_xx_049_B1_1.txt
# SD_CHN_01_XXX_INT_xx_050_B2_0.txt
# SD_ENS_01_XXX_INT_xx_001_XX_0.txt
# SD_ENS_01_XXX_INT_xx_002_XX_0.txt
# SD_ENS_01_XXX_INT_xx_003_XX_0.txt
# SD_ENS_01_XXX_INT_xx_004_XX_0.txt
# SD_ENS_01_XXX_INT_xx_005_XX_0.txt
# SD_ENS_01_XXX_INT_xx_006_XX_0.txt
# SD_ENS_01_XXX_INT_xx_007_XX_0.txt
# SD_ENS_01_XXX_INT_xx_008_XX_0.txt
# SD_ENS_01_XXX_INT_xx_009_XX_0.txt
# SD_ENS_01_XXX_INT_xx_010_XX_0.txt
# SD_ENS_01_XXX_INT_xx_011_XX_0.txt
# SD_ENS_01_XXX_INT_xx_012_XX_0.txt
# SD_ENS_01_XXX_INT_xx_013_XX_0.txt
# SD_ENS_01_XXX_INT_xx_014_XX_0.txt
# SD_ENS_01_XXX_INT_xx_015_XX_0.txt
# SD_ENS_01_XXX_INT_xx_016_XX_0.txt
# SD_ENS_01_XXX_INT_xx_017_XX_0.txt
# SD_ENS_01_XXX_INT_xx_018_XX_0.txt
# SD_ENS_01_XXX_INT_xx_019_XX_0.txt
# SD_ENS_01_XXX_INT_xx_020_XX_0.txt
# SD_HKG_01_XXX_INT_xx_001_B1_1.txt
# SD_HKG_01_XXX_INT_xx_002_B1_1.txt
# SD_HKG_01_XXX_INT_xx_003_B2_0.txt
# SD_HKG_01_XXX_INT_xx_004_B1_2.txt
# SD_HKG_01_XXX_INT_xx_005_B2_0.txt
# SD_HKG_01_XXX_INT_xx_006_B1_1.txt
# SD_HKG_01_XXX_INT_xx_007_B1_1.txt
# SD_HKG_01_XXX_INT_xx_008_B1_2.txt
# SD_HKG_01_XXX_INT_xx_009_B1_1.txt
# SD_HKG_01_XXX_INT_xx_010_B1_2.txt
# SD_HKG_01_XXX_INT_xx_011_B2_0.txt
# SD_HKG_01_XXX_INT_xx_012_B2_0.txt
# SD_HKG_01_XXX_INT_xx_013_B1_1.txt
# SD_HKG_01_XXX_INT_xx_014_B1_1.txt
# SD_HKG_01_XXX_INT_xx_015_B1_2.txt
# SD_HKG_01_XXX_INT_xx_016_B1_2.txt
# SD_HKG_01_XXX_INT_xx_017_B1_1.txt
# SD_HKG_01_XXX_INT_xx_018_B2_0.txt
# SD_HKG_01_XXX_INT_xx_019_B2_0.txt
# SD_HKG_01_XXX_INT_xx_020_B1_1.txt
# SD_HKG_01_XXX_INT_xx_021_B2_0.txt
# SD_HKG_01_XXX_INT_xx_022_B1_2.txt
# SD_HKG_01_XXX_INT_xx_023_B1_2.txt
# ===================
# [{
#         "type": "Modal verbs",
#         "annotation_utterance": "Um, because I think like communicating with people in English can facilities my learning in English because while talking I can use different words and also different sentence pattern.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": false,
#                 "rationale": "The modal verb 'can' is used to express the ability to facilitate learning, but 'facilities' should be 'facilitate' to be grammatically correct."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to use different words and sentence patterns."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And also, uh, like speaking in English because I can communicate with more people like not only people of local contest but also people from other countries, different countries or areas so that, uh, I can know more about, for example, like different culture or different places.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to communicate with more people."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to know more about different cultures or places."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, uh, most - like mostly I will speak English when I am interact with to - my professors during lessons.",
#         "annotation_tokens": [
#             {
#                 "token": "will",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'will' is used to express a future intention or plan to speak English."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, but also I sometimes will talk to my sister in English as well because, uh, we actually both like speaking in English.",
#         "annotation_tokens": [
#             {
#                 "token": "will",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'will' is used to express a future intention or plan to talk to the sister in English."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "So, uh, in daily life for example when we are in the mood of speaking in English then we also pull each other with in English instead of Cantonese.",
#         "annotation_tokens": [
#             {
#                 "token": "will",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'will' is implied to express a habitual action in daily life."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Oh, yes, of course, I'd love to.",
#         "annotation_tokens": [
#             {
#                 "token": "I'd",
#                 "grammar correctness": true,
#                 "rationale": "The contraction 'I'd' stands for 'I would', which is a modal verb used to express willingness or desire."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, to improve my speaking, I think first of all, and also the most important thing is to - really to speak more like, uh, to be brave and not, uh, feeling afraid of, uh, like for example like, speaking incorrectly like, for example like using wrong words or just, uh, to - to not to speak in front of the natives, I think first of all.",
#         "annotation_tokens": [
#             {
#                 "token": "to",
#                 "grammar correctness": true,
#                 "rationale": "The infinitive 'to' is used to express purpose or intention, which is related to modal expressions."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And the second one is to like listen more at the same time because, uh, by watching different kinds of programs you can somehow like know how people speak in different occasions.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to know how people speak in different occasions."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Um, I will prefer one-to-one because I think that - of course group discussion has its advantages that like different opinions can be exchanged and you can know, uh, like more ideas at once.",
#         "annotation_tokens": [
#             {
#                 "token": "will",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'will' is used to express a future preference."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to exchange opinions."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to know more ideas."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "However, I do think that one-to-one conversation can like the content of conversation can be more in-depth like you can really know more about what a person thinks.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the possibility of the conversation being more in-depth."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to know more about what a person thinks."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And I think also it can be more interactive because when you are in a discuss in a group, sometimes you may easily be distracted by - for example like another person like intervening or interrupting then you can be really easily distracted, yeah.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the possibility of being more interactive."},
#             {
#                 "token": "may",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'may' is used to express the possibility of being easily distracted."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to be easily distracted."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, the most important one, um, I do think speaking because like to be honest if like for example like reading, uh, for - as the technology nowadays is pretty advanced you can simply rely on, although it may not be that accurate but somehow you can still rely on tran - like translation apps to help - help you to understand the context.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to rely on translation apps."},
#             {
#                 "token": "may",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'may' is used to express the possibility of the translation not being accurate."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to rely on translation apps."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And, as for writing also, uh, the translation tool can somehow helps you with writing.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": false,
#                 "rationale": "The modal verb 'can' is used to express the ability to help with writing, but 'helps' should be 'help' to be grammatically correct."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And listening I think that if you really don't understand what people are thinking you somehow can still use gestures to help.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to use gestures to help."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "But speaking I think is most important because that's the only way you can tell people how you think.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to tell people how you think."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And, without saying, uh, by yourself people really may not be able to understand what you are - what you would like to mean or what you are trying to convey the message, yeah.",
#         "annotation_tokens": [
#             {
#                 "token": "may",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'may' is used to express the possibility of people not being able to understand."},
#             {
#                 "token": "would",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'would' is used to express a hypothetical situation or polite request."}
#         ]]
# Error in json: Expecting ',' delimiter: line 199 column 10 (char 10321)
# SD_HKG_01_XXX_INT_xx_024_B2_0.txt
# SD_HKG_01_XXX_INT_xx_025_B2_0.txt
# SD_HKG_01_XXX_INT_xx_026_B1_2.txt
# SD_HKG_01_XXX_INT_xx_027_B2_0.txt
# SD_HKG_01_XXX_INT_xx_028_B1_2.txt
# SD_HKG_01_XXX_INT_xx_029_B1_1.txt
# SD_HKG_01_XXX_INT_xx_030_B2_0.txt
# SD_IDN_01_XXX_INT_xx_001_B1_1.txt
# SD_IDN_01_XXX_INT_xx_002_B1_1.txt
# SD_IDN_01_XXX_INT_xx_003_B1_2.txt
# SD_IDN_01_XXX_INT_xx_004_B1_1.txt
# SD_IDN_01_XXX_INT_xx_005_B1_2.txt
# SD_IDN_01_XXX_INT_xx_006_B1_2.txt
# SD_IDN_01_XXX_INT_xx_007_A2.0.txt
# SD_IDN_01_XXX_INT_xx_008_A2.0.txt
# SD_IDN_01_XXX_INT_xx_009_B1_1.txt
# SD_IDN_01_XXX_INT_xx_010_B1_2.txt
# SD_IDN_01_XXX_INT_xx_011_B1_2.txt
# SD_IDN_01_XXX_INT_xx_012_B1_2.txt
# SD_IDN_01_XXX_INT_xx_013_B1_2.txt
# SD_IDN_01_XXX_INT_xx_014_B1_2.txt
# SD_IDN_01_XXX_INT_xx_015_B2_0.txt
# SD_IDN_01_XXX_INT_xx_016_B1_2.txt
# SD_IDN_01_XXX_INT_xx_017_A2.0.txt
# SD_IDN_01_XXX_INT_xx_018_A2.0.txt
# SD_IDN_01_XXX_INT_xx_019_B1_1.txt
# SD_IDN_01_XXX_INT_xx_020_B1_2.txt
# SD_IDN_01_XXX_INT_xx_021_B1_2.txt
# SD_IDN_01_XXX_INT_xx_022_B1_2.txt
# SD_IDN_01_XXX_INT_xx_023_B1_2.txt
# SD_IDN_01_XXX_INT_xx_024_B1_2.txt
# SD_IDN_01_XXX_INT_xx_025_B1_2.txt
# SD_IDN_01_XXX_INT_xx_026_A2.0.txt
# SD_IDN_01_XXX_INT_xx_027_B1_2.txt
# SD_IDN_01_XXX_INT_xx_028_B1_1.txt
# SD_IDN_01_XXX_INT_xx_029_A2.0.txt
# SD_IDN_01_XXX_INT_xx_030_B2_0.txt
# SD_JPN_01_XXX_INT_xx_001_B1_1.txt
# SD_JPN_01_XXX_INT_xx_002_B2_0.txt
# SD_JPN_01_XXX_INT_xx_003_B2_0.txt
# SD_JPN_01_XXX_INT_xx_004_B1_1.txt
# SD_JPN_01_XXX_INT_xx_005_B2_0.txt
# SD_JPN_01_XXX_INT_xx_006_B1_2.txt
# SD_JPN_01_XXX_INT_xx_007_B1_1.txt
# SD_JPN_01_XXX_INT_xx_008_A2.0.txt
# SD_JPN_01_XXX_INT_xx_009_B2_0.txt
# SD_JPN_01_XXX_INT_xx_010_B1_2.txt
# SD_JPN_01_XXX_INT_xx_011_B1_1.txt
# SD_JPN_01_XXX_INT_xx_012_A2.0.txt
# SD_JPN_01_XXX_INT_xx_013_B1_1.txt
# SD_JPN_01_XXX_INT_xx_014_B1_1.txt
# SD_JPN_01_XXX_INT_xx_015_A2.0.txt
# SD_JPN_01_XXX_INT_xx_016_B1_2.txt
# SD_JPN_01_XXX_INT_xx_017_B1_2.txt
# SD_JPN_01_XXX_INT_xx_018_B2_0.txt
# SD_JPN_01_XXX_INT_xx_019_B1_2.txt
# SD_JPN_01_XXX_INT_xx_020_B1_1.txt
# SD_JPN_01_XXX_INT_xx_021_A2.0.txt
# SD_JPN_01_XXX_INT_xx_022_A2.0.txt
# SD_JPN_01_XXX_INT_xx_023_A2.0.txt
# SD_JPN_01_XXX_INT_xx_024_B1_1.txt
# SD_JPN_01_XXX_INT_xx_025_B1_1.txt
# SD_JPN_01_XXX_INT_xx_026_B1_2.txt
# SD_JPN_01_XXX_INT_xx_027_B1_2.txt
# SD_JPN_01_XXX_INT_xx_028_B1_2.txt
# SD_JPN_01_XXX_INT_xx_029_A2.0.txt
# SD_JPN_01_XXX_INT_xx_030_A2.0.txt
# SD_JPN_01_XXX_INT_xx_031_A2.0.txt
# SD_JPN_01_XXX_INT_xx_032_A2.0.txt
# SD_JPN_01_XXX_INT_xx_033_B1_1.txt
# SD_JPN_01_XXX_INT_xx_034_B2_0.txt
# SD_JPN_01_XXX_INT_xx_035_A2.0.txt
# SD_JPN_01_XXX_INT_xx_036_B2_0.txt
# SD_JPN_01_XXX_INT_xx_037_B1_2.txt
# SD_JPN_01_XXX_INT_xx_038_A2.0.txt
# SD_JPN_01_XXX_INT_xx_039_B1_1.txt
# SD_JPN_01_XXX_INT_xx_040_A2.0.txt
# SD_JPN_01_XXX_INT_xx_041_A2.0.txt
# SD_JPN_01_XXX_INT_xx_042_A2.0.txt
# SD_JPN_01_XXX_INT_xx_043_B1_1.txt
# SD_JPN_01_XXX_INT_xx_044_A2.0.txt
# SD_JPN_01_XXX_INT_xx_045_A2.0.txt
# SD_JPN_01_XXX_INT_xx_046_B2_0.txt
# SD_JPN_01_XXX_INT_xx_047_A2.0.txt
# SD_JPN_01_XXX_INT_xx_048_A2.0.txt
# SD_JPN_01_XXX_INT_xx_049_B1_2.txt
# SD_JPN_01_XXX_INT_xx_050_B1_1.txt
# SD_JPN_01_XXX_INT_xx_051_B1_1.txt
# SD_JPN_01_XXX_INT_xx_052_B1_1.txt
# SD_JPN_01_XXX_INT_xx_053_A2.0.txt
# SD_JPN_01_XXX_INT_xx_054_B1_1.txt
# SD_JPN_01_XXX_INT_xx_055_A2.0.txt
# SD_JPN_01_XXX_INT_xx_056_B1_2.txt
# SD_JPN_01_XXX_INT_xx_057_A2.0.txt
# SD_JPN_01_XXX_INT_xx_058_B1_2.txt
# SD_JPN_01_XXX_INT_xx_059_B1_2.txt
# SD_JPN_01_XXX_INT_xx_060_B1_1.txt
# SD_JPN_01_XXX_INT_xx_061_B1_1.txt
# SD_JPN_01_XXX_INT_xx_062_B1_2.txt
# SD_JPN_01_XXX_INT_xx_063_B1_1.txt
# SD_JPN_01_XXX_INT_xx_064_A2.0.txt
# SD_JPN_01_XXX_INT_xx_065_A2.0.txt
# SD_JPN_01_XXX_INT_xx_066_B2_0.txt
# SD_JPN_01_XXX_INT_xx_067_B1_2.txt
# SD_JPN_01_XXX_INT_xx_068_B1_2.txt
# SD_JPN_01_XXX_INT_xx_069_A2.0.txt
# SD_JPN_01_XXX_INT_xx_070_B1_2.txt
# SD_JPN_01_XXX_INT_xx_071_B1_1.txt
# SD_JPN_01_XXX_INT_xx_072_B1_2.txt
# SD_JPN_01_XXX_INT_xx_073_B1_2.txt
# SD_JPN_01_XXX_INT_xx_074_B1_1.txt
# SD_JPN_01_XXX_INT_xx_075_B1_1.txt
# SD_JPN_01_XXX_INT_xx_076_B2_0.txt
# SD_JPN_01_XXX_INT_xx_077_B1_2.txt
# SD_JPN_01_XXX_INT_xx_078_B1_2.txt
# SD_JPN_01_XXX_INT_xx_079_B1_1.txt
# SD_JPN_01_XXX_INT_xx_080_B1_1.txt
# SD_JPN_01_XXX_INT_xx_081_B1_2.txt
# SD_JPN_01_XXX_INT_xx_082_B1_2.txt
# SD_JPN_01_XXX_INT_xx_083_B2_0.txt
# SD_JPN_01_XXX_INT_xx_084_B1_1.txt
# SD_JPN_01_XXX_INT_xx_085_B1_2.txt
# SD_JPN_01_XXX_INT_xx_086_A2.0.txt
# SD_JPN_01_XXX_INT_xx_087_B2_0.txt
# SD_JPN_01_XXX_INT_xx_088_B1_1.txt
# SD_JPN_01_XXX_INT_xx_089_B1_2.txt
# SD_JPN_01_XXX_INT_xx_090_B1_2.txt
# SD_JPN_01_XXX_INT_xx_091_A2.0.txt
# SD_JPN_01_XXX_INT_xx_092_A2.0.txt
# SD_JPN_01_XXX_INT_xx_093_A2.0.txt
# SD_JPN_01_XXX_INT_xx_094_A2.0.txt
# SD_JPN_01_XXX_INT_xx_095_B1_2.txt
# SD_JPN_01_XXX_INT_xx_096_A2.0.txt
# SD_JPN_01_XXX_INT_xx_097_B1_2.txt
# SD_JPN_01_XXX_INT_xx_098_B1_1.txt
# SD_JPN_01_XXX_INT_xx_099_B1_1.txt
# SD_JPN_01_XXX_INT_xx_100_B1_1.txt
# SD_KOR_01_XXX_INT_xx_001_B1_1.txt
# SD_KOR_01_XXX_INT_xx_002_B2_0.txt
# SD_KOR_01_XXX_INT_xx_003_B1_2.txt
# SD_KOR_01_XXX_INT_xx_004_B2_0.txt
# SD_KOR_01_XXX_INT_xx_005_B2_0.txt
# SD_KOR_01_XXX_INT_xx_006_B2_0.txt
# SD_KOR_01_XXX_INT_xx_007_B1_2.txt
# SD_KOR_01_XXX_INT_xx_008_B2_0.txt
# SD_KOR_01_XXX_INT_xx_009_B1_2.txt
# SD_KOR_01_XXX_INT_xx_010_B1_2.txt
# SD_KOR_01_XXX_INT_xx_011_B2_0.txt
# SD_KOR_01_XXX_INT_xx_012_B1_1.txt
# SD_KOR_01_XXX_INT_xx_013_B2_0.txt
# SD_KOR_01_XXX_INT_xx_014_B2_0.txt
# SD_KOR_01_XXX_INT_xx_015_B2_0.txt
# SD_KOR_01_XXX_INT_xx_016_B1_2.txt
# SD_KOR_01_XXX_INT_xx_017_B1_1.txt
# SD_KOR_01_XXX_INT_xx_018_B2_0.txt
# SD_KOR_01_XXX_INT_xx_019_B1_2.txt
# SD_KOR_01_XXX_INT_xx_020_B1_2.txt
# SD_MYS_01_XXX_INT_xx_001_B1_2.txt
# SD_MYS_01_XXX_INT_xx_002_B1_1.txt
# SD_MYS_01_XXX_INT_xx_003_B1_2.txt
# SD_MYS_01_XXX_INT_xx_004_B1_2.txt
# SD_MYS_01_XXX_INT_xx_005_B1_2.txt
# SD_MYS_01_XXX_INT_xx_006_B1_1.txt
# SD_MYS_01_XXX_INT_xx_007_B1_2.txt
# SD_MYS_01_XXX_INT_xx_008_B1_2.txt
# ===================
# [{
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, I'll talk about my assignment with my lecturer, I talk about assignment and then with my friends, I talk about the current issue.",
#         "annotation_tokens": [
#             {
#                 "token": "will",
#                 "grammar correctness": true,
#                 "rationale": "The contraction 'I'll' is used to express a future intention to talk about the assignment with the lecturer."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And then I asked her for her advice.",
#         "annotation_tokens": [
#             {
#                 "token": "asked",
#                 "grammar correctness": true,
#                 "rationale": "The past tense 'asked' is used to express a past action of requesting advice."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "I usually talk to my friends who is power in English, I'm trying to communicate with her and then I ask her if I have some grammatical errors, and then what if my vocabulary is too low.",
#         "annotation_tokens": [
#             {
#                 "token": "trying",
#                 "grammar correctness": true,
#                 "rationale": "The present continuous 'trying' is used to express an ongoing effort to communicate."
#             },
#             {
#                 "token": "ask",
#                 "grammar correctness": true,
#                 "rationale": "The present simple 'ask' is used to express a habitual action of asking about grammatical errors."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And then I always speak to my, hmm, actually, I have a cousin, which is, she is a teacher in English.",
#         "annotation_tokens": [
#             {
#                 "token": "always",
#                 "grammar correctness": true,
#                 "rationale": "The adverb 'always' is used to express a habitual action of speaking to the cousin."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "And then I always ask her about my English, either it is good, or it is not too good, or I need to improve it and how I'm going to improve it or something like that.",
#         "annotation_tokens": [
#             {
#                 "token": "always",
#                 "grammar correctness": true,
#                 "rationale": "The adverb 'always' is used to express a habitual action of asking about English."
#             },
#             {
#                 "token": "need",
#                 "grammar correctness": true,
#                 "rationale": "The verb 'need' is used to express an obligation or necessity to improve English."
#             },
#             {
#                 "token": "going to",
#                 "grammar correctness": true,
#                 "rationale": "The phrase 'going to' is used to express a future intention to improve English."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Discussion because when I'm doing discussion with my friends, uh, I can, you know, sometimes I can catch the word, the word.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to catch words during discussion."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Because I love that words. I love, uh, sometimes they use the idioms, and then for me, it is, it is, can improve my English besides, uh, besides I'm XXX to my friends and to lecturer.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": false,
#                 "rationale": "The modal verb 'can' is used incorrectly here as it lacks a subject and verb structure, making the sentence grammatically incorrect."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "So, I think in, in discussion, it helps me a lot and can help me a lot to improve my English.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the potential ability to help improve English."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "So, uh, you have to improve your speaking skills because you can use it around the world.",
#         "annotation_tokens": [
#             {
#                 "token": "have to",
#                 "grammar correctness": true,
#                 "rationale": "The phrase 'have to' is used to express an obligation to improve speaking skills."
#             },
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to use speaking skills around the world."
#             }
#         ]]
# Error in json: Expecting ',' delimiter: line 118 column 10 (char 5161)
# SD_MYS_01_XXX_INT_xx_009_B1_2.txt
# SD_MYS_01_XXX_INT_xx_010_B1_2.txt
# SD_MYS_01_XXX_INT_xx_011_B1_1.txt
# SD_MYS_01_XXX_INT_xx_012_B1_2.txt
# SD_MYS_01_XXX_INT_xx_013_B1_2.txt
# SD_MYS_01_XXX_INT_xx_014_B1_2.txt
# SD_MYS_01_XXX_INT_xx_015_B1_2.txt
# SD_MYS_01_XXX_INT_xx_016_B1_2.txt
# SD_MYS_01_XXX_INT_xx_017_A2.0.txt
# SD_MYS_01_XXX_INT_xx_018_B1_1.txt
# SD_MYS_01_XXX_INT_xx_019_A2.0.txt
# SD_MYS_01_XXX_INT_xx_020_B1_2.txt
# SD_PAK_01_XXX_INT_xx_001_A2.0.txt
# SD_PAK_01_XXX_INT_xx_002_A2.0.txt
# SD_PAK_01_XXX_INT_xx_003_B1_1.txt
# SD_PAK_01_XXX_INT_xx_004_B1_2.txt
# SD_PAK_01_XXX_INT_xx_005_A2.0.txt
# SD_PAK_01_XXX_INT_xx_006_B1_2.txt
# SD_PAK_01_XXX_INT_xx_007_B1_2.txt
# SD_PAK_01_XXX_INT_xx_008_B1_2.txt
# SD_PAK_01_XXX_INT_xx_009_B1_1.txt
# SD_PAK_01_XXX_INT_xx_010_B1_2.txt
# SD_PAK_01_XXX_INT_xx_011_B1_2.txt
# SD_PAK_01_XXX_INT_xx_012_A2.0.txt
# SD_PAK_01_XXX_INT_xx_013_B2_0.txt
# SD_PAK_01_XXX_INT_xx_014_B1_1.txt
# SD_PAK_01_XXX_INT_xx_015_B1_1.txt
# SD_PAK_01_XXX_INT_xx_016_B1_2.txt
# ===================
# [{
#         "type": "Modal verbs",
#         "annotation_utterance": "Sir because it's a needs our and we cannot live - I think we cannot live with - uh, without this language, so we have to learn it.",
#         "annotation_tokens": [
#             {
#                 "token": "cannot",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'cannot' is used to express the inability to live without the language."
#             },
#             {
#                 "token": "have to",
#                 "grammar correctness": true,
#                 "rationale": "The expression 'have to' is used to express obligation to learn the language."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Yes sir.  We - we have - if we want to improve our English, then we can.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to improve English."
#             }
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Sir, listening is the most important because if someone listens properly then he may be able to speak properly.",
#         "annotation_tokens": [
#             {
#                 "token": "may",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'may' is used to express a possibility of being able to speak properly."
#             }
#         ]]
# Error in json: Expecting ',' delimiter: line 37 column 10 (char 1541)
# SD_PAK_01_XXX_INT_xx_017_B1_2.txt
# SD_PAK_01_XXX_INT_xx_018_B1_2.txt
# SD_PAK_01_XXX_INT_xx_019_B1_2.txt
# ===================
# [{
#         "type": "Modal verbs",
#         "annotation_utterance": "Yeah, sure. Why not?",
#         "annotation_tokens": [
#             {
#                 "token": "sure",
#                 "grammar correctness": true,
#                 "rationale": "The word 'sure' is used to express agreement or permission."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Okay, I used to talk to my foreign cousins and I used to listen news as well in English, so that I can improve my accent, my vocabulary and other things.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to improve accent, vocabulary, and other things."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Because many people can, uh, interact with you at the same time.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability of many people to interact at the same time."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, many people can judge your language.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability of many people to judge language."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "They can help you - they can tell you that this sentence you have spoken right or this sentence you have made mistake.",
#         "annotation_tokens": [
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to help and tell."},
#             {
#                 "token": "can",
#                 "grammar correctness": true,
#                 "rationale": "The modal verb 'can' is used to express the ability to tell."}
#         ]
#     },
#     {
#         "type": "Modal verbs",
#         "annotation_utterance": "Uh, because as we are human, we live in society so we need to - it is our basic need to communicate to survive in the society.",
#         "annotation_tokens": [
#             {
#                 "token": "need",
#                 "grammar correctness": true,
#                 "rationale": "The word 'need' is used to express obligation or necessity to communicate to survive."}
#         ]]
# Error in json: Expecting ',' delimiter: line 63 column 10 (char 2661)
# SD_PAK_01_XXX_INT_xx_020_B1_2.txt
# SD_PAK_01_XXX_INT_xx_021_B1_2.txt
# SD_PAK_01_XXX_INT_xx_022_A2.0.txt
# SD_PAK_01_XXX_INT_xx_023_B1_1.txt
# SD_PAK_01_XXX_INT_xx_024_B1_2.txt
# SD_PAK_01_XXX_INT_xx_025_B1_1.txt
# SD_PHL_01_XXX_INT_xx_001_B1_2.txt
# SD_PHL_01_XXX_INT_xx_002_B2_0.txt
# SD_PHL_01_XXX_INT_xx_003_B1_2.txt
# SD_PHL_01_XXX_INT_xx_004_B1_2.txt
# SD_PHL_01_XXX_INT_xx_005_B1_2.txt
# SD_PHL_01_XXX_INT_xx_006_B1_2.txt
# SD_PHL_01_XXX_INT_xx_007_B1_2.txt
# SD_PHL_01_XXX_INT_xx_008_B2_0.txt
# SD_PHL_01_XXX_INT_xx_009_B1_2.txt
# SD_PHL_01_XXX_INT_xx_010_B1_2.txt
# SD_PHL_01_XXX_INT_xx_011_B2_0.txt
# SD_PHL_01_XXX_INT_xx_012_B1_2.txt
# SD_PHL_01_XXX_INT_xx_013_B1_2.txt
# SD_PHL_01_XXX_INT_xx_014_B1_2.txt
# SD_PHL_01_XXX_INT_xx_015_B1_2.txt
# SD_PHL_01_XXX_INT_xx_016_B1_2.txt
# SD_PHL_01_XXX_INT_xx_017_B1_2.txt
# SD_PHL_01_XXX_INT_xx_018_B1_2.txt
# SD_PHL_01_XXX_INT_xx_019_B2_0.txt
# SD_PHL_01_XXX_INT_xx_020_B1_2.txt
# SD_PHL_01_XXX_INT_xx_021_B1_2.txt
# SD_PHL_01_XXX_INT_xx_022_B1_2.txt
# SD_PHL_01_XXX_INT_xx_023_B1_2.txt
# SD_PHL_01_XXX_INT_xx_024_B1_2.txt
# SD_PHL_01_XXX_INT_xx_025_B1_2.txt
# SD_PHL_01_XXX_INT_xx_026_B1_2.txt
# SD_PHL_01_XXX_INT_xx_027_B1_2.txt
# SD_PHL_01_XXX_INT_xx_028_B1_2.txt
# SD_PHL_01_XXX_INT_xx_029_B1_2.txt
# SD_PHL_01_XXX_INT_xx_030_B1_2.txt
# SD_PHL_01_XXX_INT_xx_031_B1_2.txt
# SD_PHL_01_XXX_INT_xx_032_A2.0.txt
# SD_PHL_01_XXX_INT_xx_033_B1_2.txt
# SD_PHL_01_XXX_INT_xx_034_B1_2.txt
# SD_PHL_01_XXX_INT_xx_035_B1_2.txt
# SD_PHL_01_XXX_INT_xx_036_B1_1.txt
# SD_IDN_14_XXX_REF_xx_015_B2_0.txt
# SD_IDN_14_XXX_REF_xx_016_B1_2.txt
# SD_IDN_14_XXX_REF_xx_017_A2.0.txt
# SD_IDN_14_XXX_REF_xx_018_A2.0.txt
# SD_IDN_14_XXX_REF_xx_019_B1_1.txt
# SD_IDN_14_XXX_REF_xx_020_B1_2.txt
# SD_IDN_14_XXX_REF_xx_021_B1_2.txt
# SD_IDN_14_XXX_REF_xx_022_B1_2.txt
# SD_IDN_14_XXX_REF_xx_023_B1_2.txt
# SD_IDN_14_XXX_REF_xx_024_B1_2.txt
# SD_IDN_14_XXX_REF_xx_025_B1_2.txt
# SD_IDN_14_XXX_REF_xx_026_A2.0.txt
# SD_IDN_14_XXX_REF_xx_027_B1_2.txt
# SD_IDN_14_XXX_REF_xx_028_B1_1.txt
# SD_IDN_14_XXX_REF_xx_029_A2.0.txt
# SD_IDN_14_XXX_REF_xx_030_B2_0.txt
# SD_JPN_14_XXX_REF_xx_001_B1_1.txt
# SD_JPN_14_XXX_REF_xx_002_B2_0.txt
# SD_JPN_14_XXX_REF_xx_003_B2_0.txt
# SD_JPN_14_XXX_REF_xx_004_B1_1.txt
# SD_JPN_14_XXX_REF_xx_005_B2_0.txt
# SD_JPN_14_XXX_REF_xx_006_B1_2.txt
# SD_JPN_14_XXX_REF_xx_007_B1_1.txt
# SD_JPN_14_XXX_REF_xx_008_A2.0.txt
# SD_JPN_14_XXX_REF_xx_009_B2_0.txt
# SD_JPN_14_XXX_REF_xx_010_B1_2.txt
# SD_JPN_14_XXX_REF_xx_011_B1_1.txt
# SD_JPN_14_XXX_REF_xx_012_A2.0.txt
# SD_JPN_14_XXX_REF_xx_013_B1_1.txt
# SD_JPN_14_XXX_REF_xx_014_B1_1.txt
# SD_JPN_14_XXX_REF_xx_015_A2.0.txt
# SD_JPN_14_XXX_REF_xx_016_B1_2.txt
# SD_JPN_14_XXX_REF_xx_017_B1_2.txt
# SD_JPN_14_XXX_REF_xx_018_B2_0.txt
# SD_JPN_14_XXX_REF_xx_019_B1_2.txt
# SD_JPN_14_XXX_REF_xx_020_B1_1.txt
# SD_JPN_14_XXX_REF_xx_021_A2.0.txt
# SD_JPN_14_XXX_REF_xx_022_A2.0.txt
# SD_JPN_14_XXX_REF_xx_023_A2.0.txt
# SD_JPN_14_XXX_REF_xx_024_B1_1.txt
# SD_JPN_14_XXX_REF_xx_025_B1_1.txt
# SD_JPN_14_XXX_REF_xx_026_B1_2.txt
# SD_JPN_14_XXX_REF_xx_027_B1_2.txt
# SD_JPN_14_XXX_REF_xx_028_B1_2.txt
# SD_JPN_14_XXX_REF_xx_029_A2.0.txt
# SD_JPN_14_XXX_REF_xx_030_A2.0.txt
# SD_JPN_14_XXX_REF_xx_031_A2.0.txt
# SD_JPN_14_XXX_REF_xx_032_A2.0.txt
# SD_JPN_14_XXX_REF_xx_033_B1_1.txt
# SD_JPN_14_XXX_REF_xx_034_B2_0.txt
# SD_JPN_14_XXX_REF_xx_035_A2.0.txt
# SD_JPN_14_XXX_REF_xx_036_B2_0.txt
# SD_JPN_14_XXX_REF_xx_037_B1_2.txt
# SD_JPN_14_XXX_REF_xx_038_A2.0.txt
# SD_JPN_14_XXX_REF_xx_039_B1_1.txt
# SD_JPN_14_XXX_REF_xx_040_A2.0.txt
# SD_JPN_14_XXX_REF_xx_041_A2.0.txt
# SD_JPN_14_XXX_REF_xx_042_A2.0.txt
# SD_JPN_14_XXX_REF_xx_043_B1_1.txt
# SD_JPN_14_XXX_REF_xx_044_A2.0.txt
# SD_JPN_14_XXX_REF_xx_045_A2.0.txt
# SD_JPN_14_XXX_REF_xx_046_B2_0.txt
# SD_JPN_14_XXX_REF_xx_047_A2.0.txt
# SD_JPN_14_XXX_REF_xx_048_A2.0.txt
# SD_JPN_14_XXX_REF_xx_049_B1_2.txt
# SD_JPN_14_XXX_REF_xx_050_B1_1.txt
# SD_JPN_14_XXX_REF_xx_051_B1_1.txt
# SD_JPN_14_XXX_REF_xx_052_B1_1.txt
# SD_JPN_14_XXX_REF_xx_053_A2.0.txt
# SD_JPN_14_XXX_REF_xx_054_B1_1.txt
# SD_JPN_14_XXX_REF_xx_055_A2.0.txt
# SD_JPN_14_XXX_REF_xx_056_B1_2.txt
# SD_JPN_14_XXX_REF_xx_057_A2.0.txt
# SD_JPN_14_XXX_REF_xx_058_B1_2.txt
# SD_JPN_14_XXX_REF_xx_059_B1_2.txt
# SD_JPN_14_XXX_REF_xx_060_B1_1.txt
# SD_JPN_14_XXX_REF_xx_061_B1_1.txt
# SD_JPN_14_XXX_REF_xx_062_B1_2.txt
# SD_JPN_14_XXX_REF_xx_063_B1_1.txt
# SD_JPN_14_XXX_REF_xx_064_A2.0.txt
# SD_JPN_14_XXX_REF_xx_065_A2.0.txt
# SD_JPN_14_XXX_REF_xx_066_B2_0.txt
# SD_JPN_14_XXX_REF_xx_067_B1_2.txt
# SD_JPN_14_XXX_REF_xx_068_B1_2.txt
# SD_JPN_14_XXX_REF_xx_069_A2.0.txt
# SD_JPN_14_XXX_REF_xx_070_B1_2.txt
# SD_JPN_14_XXX_REF_xx_071_B1_1.txt
# SD_JPN_14_XXX_REF_xx_072_B1_2.txt
# SD_JPN_14_XXX_REF_xx_073_B1_2.txt
# SD_JPN_14_XXX_REF_xx_074_B1_1.txt
# SD_JPN_14_XXX_REF_xx_075_B1_1.txt
# SD_JPN_14_XXX_REF_xx_076_B2_0.txt
# SD_JPN_14_XXX_REF_xx_077_B1_2.txt
# SD_JPN_14_XXX_REF_xx_078_B1_2.txt
# SD_JPN_14_XXX_REF_xx_079_B1_1.txt
# SD_JPN_14_XXX_REF_xx_080_B1_1.txt
# SD_JPN_14_XXX_REF_xx_081_B1_2.txt
# SD_JPN_14_XXX_REF_xx_082_B1_2.txt
# SD_JPN_14_XXX_REF_xx_083_B2_0.txt
# SD_JPN_14_XXX_REF_xx_084_B1_1.txt
# SD_JPN_14_XXX_REF_xx_085_B1_2.txt
# SD_JPN_14_XXX_REF_xx_086_A2.0.txt
# SD_JPN_14_XXX_REF_xx_087_B2_0.txt
# SD_JPN_14_XXX_REF_xx_088_B1_1.txt
# SD_JPN_14_XXX_REF_xx_089_B1_2.txt
# SD_JPN_14_XXX_REF_xx_090_B1_2.txt
# SD_JPN_14_XXX_REF_xx_091_A2.0.txt
# SD_JPN_14_XXX_REF_xx_092_A2.0.txt
# SD_JPN_14_XXX_REF_xx_093_A2.0.txt
# SD_JPN_14_XXX_REF_xx_094_A2.0.txt
# SD_JPN_14_XXX_REF_xx_095_B1_2.txt
# SD_JPN_14_XXX_REF_xx_096_A2.0.txt
# SD_JPN_14_XXX_REF_xx_097_B1_2.txt
# SD_JPN_14_XXX_REF_xx_098_B1_1.txt
# SD_JPN_14_XXX_REF_xx_099_B1_1.txt
# SD_JPN_14_XXX_REF_xx_100_B1_1.txt
# SD_KOR_14_XXX_REF_xx_001_B1_1.txt
# SD_KOR_14_XXX_REF_xx_002_B2_0.txt
# SD_KOR_14_XXX_REF_xx_003_B1_2.txt
# SD_KOR_14_XXX_REF_xx_004_B2_0.txt
# SD_KOR_14_XXX_REF_xx_005_B2_0.txt
# SD_KOR_14_XXX_REF_xx_006_B2_0.txt
# SD_KOR_14_XXX_REF_xx_007_B1_2.txt
# SD_KOR_14_XXX_REF_xx_008_B2_0.txt
# SD_KOR_14_XXX_REF_xx_009_B1_2.txt
# SD_KOR_14_XXX_REF_xx_010_B1_2.txt
# SD_KOR_14_XXX_REF_xx_011_B2_0.txt
# SD_KOR_14_XXX_REF_xx_012_B1_1.txt
# SD_KOR_14_XXX_REF_xx_013_B2_0.txt
# SD_KOR_14_XXX_REF_xx_014_B2_0.txt
# SD_KOR_14_XXX_REF_xx_015_B2_0.txt
# SD_KOR_14_XXX_REF_xx_016_B1_2.txt
# SD_KOR_14_XXX_REF_xx_017_B1_1.txt
# SD_KOR_14_XXX_REF_xx_018_B2_0.txt
# SD_KOR_14_XXX_REF_xx_019_B1_2.txt
# SD_KOR_14_XXX_REF_xx_020_B1_2.txt
# SD_MYS_14_XXX_REF_xx_001_B1_2.txt
# SD_MYS_14_XXX_REF_xx_002_B1_1.txt
# SD_MYS_14_XXX_REF_xx_003_B1_2.txt
# SD_MYS_14_XXX_REF_xx_004_B1_2.txt
# SD_MYS_14_XXX_REF_xx_005_B1_2.txt
# SD_MYS_14_XXX_REF_xx_006_B1_1.txt
# SD_MYS_14_XXX_REF_xx_007_B1_2.txt
# SD_MYS_14_XXX_REF_xx_008_B1_2.txt
# SD_MYS_14_XXX_REF_xx_009_B1_2.txt
# SD_MYS_14_XXX_REF_xx_010_B1_2.txt
# SD_MYS_14_XXX_REF_xx_011_B1_1.txt
# SD_MYS_14_XXX_REF_xx_012_B1_2.txt
# SD_MYS_14_XXX_REF_xx_013_B1_2.txt
# SD_MYS_14_XXX_REF_xx_014_B1_2.txt
# SD_MYS_14_XXX_REF_xx_015_B1_2.txt
# SD_MYS_14_XXX_REF_xx_016_B1_2.txt
# SD_MYS_14_XXX_REF_xx_017_A2.0.txt
# SD_MYS_14_XXX_REF_xx_018_B1_1.txt
# SD_MYS_14_XXX_REF_xx_019_A2.0.txt
# SD_MYS_14_XXX_REF_xx_020_B1_2.txt
# SD_PAK_14_XXX_REF_xx_001_A2.0.txt
# SD_PAK_14_XXX_REF_xx_002_A2.0.txt
# SD_PAK_14_XXX_REF_xx_003_B1_1.txt
# SD_PAK_14_XXX_REF_xx_004_B1_2.txt
# SD_PAK_14_XXX_REF_xx_005_A2.0.txt
# SD_PAK_14_XXX_REF_xx_006_B1_2.txt
# SD_PAK_14_XXX_REF_xx_007_B1_2.txt
# SD_PAK_14_XXX_REF_xx_008_B1_2.txt
# SD_PAK_14_XXX_REF_xx_009_B1_1.txt
# SD_PAK_14_XXX_REF_xx_010_B1_2.txt
# SD_PAK_14_XXX_REF_xx_011_B1_2.txt
# SD_PAK_14_XXX_REF_xx_012_A2.0.txt
# SD_PAK_14_XXX_REF_xx_013_B2_0.txt
# SD_PAK_14_XXX_REF_xx_014_B1_1.txt
# SD_PAK_14_XXX_REF_xx_015_B1_1.txt
# SD_PAK_14_XXX_REF_xx_016_B1_2.txt
# SD_PAK_14_XXX_REF_xx_017_B1_2.txt
# SD_PAK_14_XXX_REF_xx_018_B1_2.txt
# SD_PAK_14_XXX_REF_xx_019_B1_2.txt
# SD_PAK_14_XXX_REF_xx_020_B1_2.txt
# SD_PAK_14_XXX_REF_xx_021_B1_2.txt
# SD_PAK_14_XXX_REF_xx_022_A2.0.txt
# SD_PAK_14_XXX_REF_xx_023_B1_1.txt
# SD_PAK_14_XXX_REF_xx_024_B1_2.txt
# SD_PAK_14_XXX_REF_xx_025_B1_1.txt
# SD_PHL_14_XXX_REF_xx_001_B1_2.txt
# SD_PHL_14_XXX_REF_xx_002_Void_B2_0.txt
# SD_PHL_14_XXX_REF_xx_003_B1_2.txt
# SD_PHL_14_XXX_REF_xx_004_B1_2.txt
# SD_PHL_14_XXX_REF_xx_005_B1_2.txt
# SD_PHL_14_XXX_REF_xx_006_B1_2.txt
# SD_PHL_14_XXX_REF_xx_007_B1_2.txt
# SD_PHL_14_XXX_REF_xx_008_B2_0.txt
# SD_PHL_14_XXX_REF_xx_009_B1_2.txt
# SD_PHL_14_XXX_REF_xx_010_B1_2.txt
# SD_PHL_14_XXX_REF_xx_011_B2_0.txt
# SD_PHL_14_XXX_REF_xx_012_B1_2.txt
# SD_PHL_14_XXX_REF_xx_013_B1_2.txt
# SD_PHL_14_XXX_REF_xx_014_B1_2.txt
# SD_PHL_14_XXX_REF_xx_015_B1_2.txt
# SD_PHL_14_XXX_REF_xx_016_B1_2.txt
# SD_PHL_14_XXX_REF_xx_017_B1_2.txt
# SD_PHL_14_XXX_REF_xx_018_B1_2.txt
# SD_PHL_14_XXX_REF_xx_019_B2_0.txt
# SD_PHL_14_XXX_REF_xx_020_B1_2.txt
# SD_PHL_14_XXX_REF_xx_021_B1_2.txt
# SD_PHL_14_XXX_REF_xx_022_B1_2.txt
# SD_PHL_14_XXX_REF_xx_023_B1_2.txt
# SD_PHL_14_XXX_REF_xx_024_B1_2.txt
# SD_PHL_14_XXX_REF_xx_025_B1_2.txt
# SD_PHL_14_XXX_REF_xx_026_B1_2.txt
# SD_PHL_14_XXX_REF_xx_027_B1_2.txt
# SD_PHL_14_XXX_REF_xx_028_B1_2.txt
# SD_PHL_14_XXX_REF_xx_029_B1_2.txt
# SD_PHL_14_XXX_REF_xx_030_B1_2.txt
# SD_PHL_14_XXX_REF_xx_031_B1_2.txt
# SD_PHL_14_XXX_REF_xx_032_A2.0.txt
# SD_PHL_14_XXX_REF_xx_033_B1_2.txt
# SD_PHL_14_XXX_REF_xx_034_B1_2.txt
# SD_PHL_14_XXX_REF_xx_035_B1_2.txt
# SD_PHL_14_XXX_REF_xx_036_B1_1.txt
# SD_PHL_14_XXX_REF_xx_037_B1_2.txt
# SD_PHL_14_XXX_REF_xx_038_B1_2.txt
# SD_PHL_14_XXX_REF_xx_039_B1_2.txt
# SD_PHL_14_XXX_REF_xx_040_B1_2.txt
# SD_THA_14_XXX_REF_xx_001_B1_1.txt
# SD_THA_14_XXX_REF_xx_002_B1_2.txt
# SD_THA_14_XXX_REF_xx_003_B1_2.txt
# SD_THA_14_XXX_REF_xx_004_B1_2.txt
# SD_THA_14_XXX_REF_xx_005_A2.0.txt
# SD_THA_14_XXX_REF_xx_006_B1_1.txt
# SD_THA_14_XXX_REF_xx_007_A2.0.txt
# SD_THA_14_XXX_REF_xx_008_A2.0.txt
# SD_THA_14_XXX_REF_xx_009_A2.0.txt
# SD_THA_14_XXX_REF_xx_010_B1_1.txt
# SD_THA_14_XXX_REF_xx_011_B1_1.txt
# SD_THA_14_XXX_REF_xx_012_B1_1.txt
# SD_THA_14_XXX_REF_xx_013_B1_1.txt
# SD_THA_14_XXX_REF_xx_014_B1_2.txt
# SD_THA_14_XXX_REF_xx_015_B1_2.txt
# SD_THA_14_XXX_REF_xx_016_A2.0.txt
# SD_THA_14_XXX_REF_xx_017_B1_1.txt
# SD_THA_14_XXX_REF_xx_018_B1_1.txt
# SD_THA_14_XXX_REF_xx_019_B1_2.txt
# SD_THA_14_XXX_REF_xx_020_B1_2.txt
# SD_THA_14_XXX_REF_xx_021_B1_2.txt
# SD_THA_14_XXX_REF_xx_022_B1_1.txt
# SD_THA_14_XXX_REF_xx_023_A2.0.txt
# SD_THA_14_XXX_REF_xx_024_B1_2.txt
# SD_THA_14_XXX_REF_xx_025_B1_1.txt
# SD_THA_14_XXX_REF_xx_026_B1_2.txt
# SD_THA_14_XXX_REF_xx_027_B1_2.txt
# SD_THA_14_XXX_REF_xx_028_B1_2.txt
# SD_THA_14_XXX_REF_xx_029_B1_2.txt
# SD_THA_14_XXX_REF_xx_030_B1_2.txt
# SD_THA_14_XXX_REF_xx_031_B1_2.txt
# SD_THA_14_XXX_REF_xx_032_B1_2.txt
# SD_THA_14_XXX_REF_xx_033_B1_1.txt
# SD_THA_14_XXX_REF_xx_034_B1_2.txt
# SD_THA_14_XXX_REF_xx_035_B1_2.txt
# SD_THA_14_XXX_REF_xx_036_B2_0.txt
# SD_THA_14_XXX_REF_xx_037_B2_0.txt
# SD_THA_14_XXX_REF_xx_038_B1_2.txt
